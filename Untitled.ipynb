# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Countries_of_the_world_1970 - imputed_international_data_70 (2).csv")

# %%
df.head(10)
# Out:
#         Entity  indiv_libs_vdem_owid  electdem_vdem_owid  libdem_vdem_owid  \
# 0  Afghanistan                 0.266               0.160             0.104
# 1      Albania                 0.006               0.173             0.055
# 2      Algeria                 0.428               0.084             0.065
# 3       Angola                 0.024               0.010             0.035
# 4    Argentina                 0.354               0.105             0.086
# 5      Armenia                 0.094               0.102             0.024
# 6    Australia                 0.980               0.860             0.807
# 7      Austria                 0.949               0.843             0.728
# 8   Azerbaijan                 0.094               0.102             0.024
# 9      Bahrain                 0.449               0.024               NaN
#
#     Countries  Economic.Freedom.Summary.Index  Government.consumption  \
# 0         NaN                        5.506573                6.393604
# ...

# %%
df.tail(20)
# Out:
#                       Entity  indiv_libs_vdem_owid  electdem_vdem_owid  \
# 162             Turkmenistan                 0.094               0.102
# 163                   Uganda                 0.311               0.200
# 164                  Ukraine                 0.094               0.102
# 165           United Kingdom                 0.940               0.830
# 166            United States                 0.919               0.709
# 167                  Uruguay                 0.643               0.597
# 168               Uzbekistan                 0.094               0.102
# 169                  Vanuatu                 0.830               0.154
# 170                Venezuela                 0.844               0.689
# 171                  Vietnam                 0.120               0.219
# 172                    Yemen                 0.152               0.028
# 173  Yemen People's Republic                 0.221               0.078
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 43 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Entity                                                182 non-null    object
#  1   indiv_libs_vdem_owid                                  177 non-null    float64
#  2   electdem_vdem_owid                                    177 non-null    float64
#  3   libdem_vdem_owid                                      175 non-null    float64
#  4   Countries                                             165 non-null    object
#  5   Economic.Freedom.Summary.Index                        182 non-null    float64
#  6   Government.consumption                                182 non-null    float64
#  7   Transfers.and.subsidies                               182 non-null    float64
# ...

# %%
df['new_lib_dem'] = df['libdem_vdem_owid'].apply(lambda x: x *100)

# %%
df['new_lib_dem']
# Out:
# 0      10.4
# 1       5.5
# 2       6.5
# 3       3.5
# 4       8.6
#        ...
# 177     NaN
# 178     NaN
# 179     NaN
# 180     NaN
# 181     NaN
# Name: new_lib_dem, Length: 182, dtype: float64

# %%
df['libdem_vdem_owid']
# Out:
# 0      0.104
# 1      0.055
# 2      0.065
# 3      0.035
# 4      0.086
#        ...
# 177      NaN
# 178      NaN
# 179      NaN
# 180      NaN
# 181      NaN
# Name: libdem_vdem_owid, Length: 182, dtype: float64

# %%
df['new_lib_dem'] = df['libdem_vdem_owid']*100

# %%
df['new_lib_dem']
# Out:
# 0      10.4
# 1       5.5
# 2       6.5
# 3       3.5
# 4       8.6
#        ...
# 177     NaN
# 178     NaN
# 179     NaN
# 180     NaN
# 181     NaN
# Name: new_lib_dem, Length: 182, dtype: float64

# %%
df['libdem_vdem_owid'].head(10)
# Out:
# 0    0.104
# 1    0.055
# 2    0.065
# 3    0.035
# 4    0.086
# 5    0.024
# 6    0.807
# 7    0.728
# 8    0.024
# 9      NaN
# Name: libdem_vdem_owid, dtype: float64

# %%
df['lib_dem_allies'] = df["libdem_vdem_owid"].apply(lambda x: x*100 if x < .5 else np.nan)

# %%
df['lib_dem_allies'].head(10)
# Out:
# 0    10.4
# 1     5.5
# 2     6.5
# 3     3.5
# 4     8.6
# 5     2.4
# 6     NaN
# 7     NaN
# 8     2.4
# 9     NaN
# Name: lib_dem_allies, dtype: float64

# %%
def cond_mult(df):
    if df["alliance"] == "US ally":
        return df["libdem_vdem_owid"]*100
    else:
        return np.nan

# %%
df.apply(cond_mult)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df.apply(cond_mult)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:798, in FrameApply.apply_standard(self)
# ...

# %%
condition1 = df['alliance'] == "US ally"
function1 = lambda x: x * 100
function2 = lambda x: x + 5
# Apply the functions/logic based on conditions and create the new column
df['lib_dem_allies'] = np.where(condition1,function1(df["libdem_vdem_owid"]),np.nan)

# %%
df['lib_dem_allies'].head(20)
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      8.6
# 5      NaN
# 6     80.7
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11    61.8
# 12     NaN
# 13    77.3
# 14     NaN
# 15     NaN
# 16     2.8
# 17     NaN
# 18     NaN
# 19     8.2
# Name: lib_dem_allies, dtype: float64
