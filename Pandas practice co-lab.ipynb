# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
house_df = pd.read_csv("Copy of Housing - Housing.csv")

# %%
loan_df = pd.read_csv("loan_approval_dataset.csv")

# %%
house_df.head(10)
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
loan_df.head(10)
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
# 5        6                  0       Graduate            Yes        4800000
# 6        7                  5       Graduate             No        8700000
# 7        8                  2       Graduate            Yes        5700000
# 8        9                  0       Graduate            Yes         800000
# 9       10                  5   Not Graduate             No        1100000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# ...

# %%
house_df['guest_dummyv']=house_df['guestroom'].apply(lambda x: 1 if x == 'yes' else 0)

# %%
house_df['guest_dummyv']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 540    0
# 541    0
# 542    0
# 543    0
# 544    0
# Name: guest_dummyv, Length: 545, dtype: int64

# %%
house_df['guest_dummyv']= np.where(house_df["guestroom"] == "yes",1,0)
house_df['guest_dummyv']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 540    0
# 541    0
# 542    0
# 543    0
# 544    0
# Name: guest_dummyv, Length: 545, dtype: int32

# %%
vector1 = house_df["guestroom"]+house_df["mainroad"]+house_df["basement"]



house_df['sum_of_features']= np.select([vector1.str.count('yes') ==3,vector1.str.count('yes') ==2,vector1.str.count('yes') ==1],[3,2,1],default=0)

# %%
(house_df["guestroom"]+house_df["mainroad"]+house_df["basement"]).count('yes')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 (house_df["guestroom"]+house_df["mainroad"]+house_df["basement"]).count('yes')
#
# TypeError: Series.count() takes 1 positional argument but 2 were given

# %%
'ababaaaa'.count('aa')
# Out:
# 2

# %%
house_df['sum_of_features']
# Out:
# 0      1
# 1      1
# 2      2
# 3      2
# 4      3
#       ..
# 540    2
# 541    0
# 542    1
# 543    0
# 544    1
# Name: sum_of_features, Length: 545, dtype: int32
